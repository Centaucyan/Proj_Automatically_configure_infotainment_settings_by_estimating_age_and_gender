# %%
import os
from deepface import DeepFace

os.getcwd()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785314807.650442   94871 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785314807.736526   94871 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785314810.172856   94871 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# '/media/tae/Tae_inHDD/Tae_ws/Ubuntu/Proj_Age_and_gender_estimation_based_on_facial_images/test'

# %%
# 1. images 폴더 경로 지정 (test.ipynb 위치 기준)
images_dir = "../images"
# 지원하는 이미지 확장자 목록
valid_extensions = ('.png', '.jpg', '.jpeg', '.webp', '.bmp')

if os.path.exists(images_dir):
    # 폴더 내 이미지 파일 목록 필터링
    image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(valid_extensions)])
    
    if not image_files:
        print(f"❌ '{images_dir}' 폴더에 분석할 이미지 파일이 없습니다.")
    else:
        print(f"📂 총 {len(image_files)}개의 이미지 파일을 발견했습니다. 분석을 시작합니다...\n")
        
        # 2. 이미지 파일별로 순회하며 분석 실행
        for i, file_name in enumerate(image_files, 1):
            img_path = os.path.join(images_dir, file_name)
            
            print(f"==================================================")
            print(f"[{i}/{len(image_files)}] 📷 파일 분석 중: {file_name}")
            print(f"==================================================")
            
            try:
                # DeepFace 나이 및 성별 분석 실행
                results = DeepFace.analyze(
                    img_path = img_path,
                    actions = ['age', 'gender'],
                    detector_backend = 'retinaface', # 탐지기 변경 시 'retinaface' 또는 'mediapipe'
                    enforce_detection = False
                )
                # 3. 결과 출력
                for idx, result in enumerate(results, 1):
                    age = result['age']
                    gender = result['dominant_gender']
                    gender_scores = result['gender']
                    print(f"  [얼굴 #{idx}]")
                    print(f"  • 추정 나이 : {age} 세")
                    print(f"  • 추정 성별 : {gender} (남성 {gender_scores['Man']:.1f}% / 여성 {gender_scores['Woman']:.1f}%)")
                print("\n")
            except Exception as e:
                print(f"  ❌ 분석 실패 ({file_name}): {e}\n")
                
else:
    print(f"❌ '{images_dir}' 경로를 찾을 수 없습니다.")
# Out:
# 📂 총 6개의 이미지 파일을 발견했습니다. 분석을 시작합니다...
#
# ==================================================
# [1/6] 📷 파일 분석 중: Moon_1.webp
# ==================================================
# E0000 00:00:1785314813.992118   94871 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Action: age:   0%|          | 0/2 [00:00<?, ?it/s]    W0000 00:00:1785314824.704588   94871 cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# W0000 00:00:1785314825.117580   94871 cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# W0000 00:00:1785314825.272631   94871 cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# W0000 00:00:1785314826.594279   94871 cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# Action: gender:  50%|█████     | 1/2 [00:03<00:03,  3.08s/it]W0000 00:00:1785314827.776821   94871 cpu_allocator_impl.cc:82] Allocation of 411041792 exceeds 10% of free system memory.
# Action: gender: 100%|██████████| 2/2 [00:05<00:00,  2.97s/it]
#   [얼굴 #1]
#   • 추정 나이 : 29 세
#   • 추정 성별 : Woman (남성 0.0% / 여성 100.0%)
#
#
# ==================================================
# [2/6] 📷 파일 분석 중: Moon_2.webp
# ==================================================
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.65it/s]
#   [얼굴 #1]
#   • 추정 나이 : 31 세
#   • 추정 성별 : Woman (남성 0.0% / 여성 100.0%)
#
#
# ==================================================
# [3/6] 📷 파일 분석 중: Park_1_like_manhair.jpg
# ==================================================
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.42it/s]
#   [얼굴 #1]
#   • 추정 나이 : 27 세
#   • 추정 성별 : Woman (남성 16.1% / 여성 83.9%)
#
#
# ==================================================
# [4/6] 📷 파일 분석 중: Son_1.webp
# ==================================================
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.65it/s]
#   [얼굴 #1]
#   • 추정 나이 : 33 세
#   • 추정 성별 : Man (남성 99.7% / 여성 0.3%)
#
#
# ==================================================
# [5/6] 📷 파일 분석 중: Son_2.jpg
# ==================================================
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
#   [얼굴 #1]
#   • 추정 나이 : 32 세
#   • 추정 성별 : Man (남성 99.9% / 여성 0.1%)
#
#
# ==================================================
# [6/6] 📷 파일 분석 중: Yoon_1_like_manhair.jpg
# ==================================================
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.38it/s]
#   [얼굴 #1]
#   • 추정 나이 : 31 세
#   • 추정 성별 : Man (남성 89.8% / 여성 10.2%)
